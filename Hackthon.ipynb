# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

rural_df = pd.read_csv("/content/sample_data/Untitled spreadsheet - Sheet1 (1).csv")
urban_df = pd.read_csv("/content/sample_data/Untitled spreadsheet - Sheet1.csv")

print(rural_df)
print()
print(urban_df)
# Out:
#    -      Villages   Schools  Attendance  Male  Female  Devices  Faculty
# 0  1    Diskit,Leh         5        2000  1200     800      100       30
# 1  2  Gorakhnath,HR       45       12000  7000    5000      500       70
# 2  3  Santpur,Bihar        0           0     0       0        0        0
# 3  4     Chetlat,IC        1          20    14       6        2        3
# 4  5      Kuneri,GJ        7        5000  3400    1600       90      150
#
#    -           City  Schools  Attendance     Male   Female  Devices  Faculty
# 0  1  Chandigarh,PB      500      200000   120000    80000    10000     3000
# 1  2     Gurgaon,HR      450       12000     7000     5000     2500     7000
# 2  3    Patna,Bihar      600      500000   300000   200000     4600     5000
# 3  4      Mumbai,MH     1000     5000000  3200000  1800000     9200    10000
# 4  5   Ahmedabad,GJ      700      500000   370000   130000     6700     3400

# %%
plt.figure(dpi = 100)
plt.title("Bargraph for availabe devices in a rural school")
plt.bar(rural_df['Schools'],rural_df['Devices'])
plt.show()

# %%
plt.figure(dpi = 100)
plt.title("Bargraph for availabe teachers in a rural school")
plt.bar(rural_df['Schools'],rural_df['Faculty'])
plt.show()

# %%
plt.figure(dpi = 100)
plt.title("Bargraph for availabe devices in a urban school")
plt.bar(urban_df['Schools'],urban_df['Devices'])
plt.show()

# %%
plt.figure(dpi = 100)
plt.title("Bargraph for availabe faculty in a urban school")
plt.bar(urban_df['Schools'],urban_df['Faculty'])
plt.show()
